# %% [markdown]
# <h1>Display Business Unit Mapped</h1>
# <p></p>
# B2B:
# <ul>
# <li>Client Solutions Group</li>
# <li>Commercial</li>
# <li>Dell Tech Concierge</li>
# <li>HSB</li>
# <li>Infrastructure Solutions Group</li>
# <li>Medium Business</li>
# </ul>
#
#
# <p>CSB:</p>
# <ul>
# <li>Alienware</li>
# <li>Brand</li>
# <li>onsumer</li>
# <li>Consumer Small Business</li>
# <li>Gaming</li>
# <li>Member Purchase Program</li>
# <li>Other</li>
# <li>Small & Medium Business</li>
# <li>Small Business</li>
# </ul>
#
# <p>Other:</p>
# <ul>
# <li>Outlet</li>
# <li>Outlet Consumer Small Business</li>
# <li>Retail</li>
# <li>Outlet Consumer</li>
# <li>RETAIL</li>
# </ul>
#
# <p></p>
# <h1>Display Dell Vehicle Mapped</h1>
# <ul>
# <li>Display</li>
# <li>Display Mobile</li>
# <li>Social</li>
# </ul>

# %%
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings('ignore')

# %%
df = pd.read_excel(r'C:\Users\rafael_fagundes\Downloads\US Spend & Rev FY24.xlsx', sheet_name='Sheet 1')

# %% [markdown]
# ### Filter by Display and Social

# %%
df_filter = df[df['Display Dell Vehicle Mapped'].isin(['Display','Display Mobile','Social'])]

# %% [markdown]
# ### BU Split

# %%
B2B = ['Client Solutions Group', 'Commercial', 'Dell Tech Concierge', 'HSB', 'Infrastructure Solutions Group', 'Medium Business']
CSB = ['Alienware', 'Brand', 'Consumer', 'Consumer Small Business', 'Gaming', 'Member Purchase Program', 'Other', 'Small & Medium Business', 'Small Business']

df_filter['LOB'] = np.where(df_filter['Display Business Unit Mapped'].isin(B2B), 'B2B', 
                            np.where(df_filter['Display Business Unit Mapped'].isin(CSB), 'CSB', 'Other'))

# %% [markdown]
# ### Audience Category Types

# %%
#Get Category Type
str_categories = '(CRM-1PD-CRM|EMAIL-1PD-CRM|RETARGET-1PD-RETARGET|MEDIA-1PD-MEDIA|LAPSED-1PD-PIXEL|PUBLISHER-2PD|DMP-2PD-AUDIENCE|ABM-2PD-AUDIENCE|KCT-3PD-CONTEXTUAL|PROXIMITY-3PD-CONTEXTUAL|CATEGORY-3PD-CONTEXTUAL|DOMAIN-3PD-CONTEXTUAL|IN-MARKET-3PD-CONTEXTUAL|AFFINITY-3PD-BEHAVIOR|PROXIMITY-3PD-BEHAVIOR|SITE-IN-MARKET-3PD-BEHAVIOR|IN-MARKET-3PD-BEHAVIOR|DMP-3PD-AUDIENCE|DMP-3PD-LAL|ROS-3PD-PMP|AUDIO-3PD-RETARGET-EXPOSED|CTV-3PD-RETARGET-EXPOSED|DIGITAL-3PD-RETARGET-EXPOSED|DOOH-3PD-RETARGET-EXPOSED|MEDIA-3PD-RETARGET-EXPOSED|VIDEO-3PD-RETARGET-EXPOSED|ABM-3PD-AUDIENCE|RON-PMP|ROS-PMP|KCT-SEARCH|CONQUESTING|SPONSORSHIP|PERSONA-1PD-RETARGET|PIXEL-3PD-LAL|KCT-2PD-CONTEXTUAL)'

df_filter['Audience Type'] = df_filter['Media Buy Name'].replace(' ', '-', regex=True).str.upper().str.extract(str_categories)

# %%
df_filter.head()
# Out:
#       Data Stream Parent Stream Global Country (Calc) Global Region (Calc)  \
# 73768              Empty Parent         United States             Americas
# 73769              Empty Parent         United States             Americas
# 73771              Empty Parent         United States             Americas
# 73772              Empty Parent         United States             Americas
# 73773              Empty Parent         United States             Americas
#
#       Display Business Unit Mapped Global Audience Type (Calc)  \
# 73768                     Consumer                         3PD
# 73769                   Commercial                         3PD
# 73771                   Commercial                         1PD
# 73772                        Other                       Other
# 73773      Consumer Small Business                         1PD
#
#                                            Campaign Name  \
# 73768    2023_Q3_US_CON_AP_DISPLAY-MOBILE_PROSPECTING_NA
# 73769  2024_1H_US_COM_AP_DISPLAY_PROSPECTING-ENGAGE_D...
# 73771  2024_1H_US_COM_BSP_DISPLAY_RETARGETING-ENGAGE_...
# 73772  2024_Q1_US_RETAIL_HP_DISPLAY_PROSPECTING_MULTI...
# 73773       2023_Q4_US_CSB_AP_DISPLAY_PROSPECTING_NA_CON
#
#             Display Funnel Mapped Display Dell Vehicle Mapped  \
# 73768            Active Prospects              Display Mobile
# 73769            Active Prospects                     Display
# 73771     Brand Seeker/Purchasers                     Display
# 73772  High Propsensity Prospects                     Display
# 73773            Active Prospects                     Display
#
#       Display Site Name Mapped Dell Fiscal Quarter Week  ...  \
# 73768      Display & Video 360                      W01  ...
# 73769                Quantcast                      W08  ...
# 73771                Quantcast                      W05  ...
# 73772      Display & Video 360                      W13  ...
# 73773            Verizon Media                      W02  ...
#
#       Campaign Advertiser ID  \
# 73768              9694607.0
# 73769             11531739.0
# 73771             11531739.0
# 73772              9685813.0
# 73773              9694607.0
#
#                                           Media Buy Name Campaign Status  \
# 73768  DV360_IN MARKET-3PD CONTEXTUAL_HTML5 BANNER_30...             NaN
# 73769  QUANTCAST_CATEGORY-3PD CONTEXTUAL_VID IN-STREA...             NaN
# 73771  QUANTCAST_RETARGET-1PD RETARGET_STANDARD BANNE...             NaN
# 73772  DV360_CONQUESTING_HTML5 BANNER_320x50_DCPM_NVI...             NaN
# 73773  VERIZON_RETARGET-1PD RETARGET_HTML5 BANNER_160...             NaN
#
#       Global Tactic (Calc)  Global Tactic CSB (Calc)  \
# 73768      Standard Search                     Brand
# 73769      Standard Search                     Brand
# 73771      Standard Search                     Brand
# 73772      Standard Search                     Brand
# 73773      Standard Search                     Brand
#
#       Global Tactic V2 B2B (Calc)  Actual Spend (GCSB) (Calc)  \
# 73768                         NaN                    0.000000
# 73769                  ENGAGEMENT                  562.520000
# 73771                  ENGAGEMENT                    8.300000
# 73772                 PROSPECTING                  137.522347
# 73773                 PROSPECTING                    0.000000
#
#       LC True Revenue BQ (GCSB) (Calc)  LOB             Audience Type
# 73768                              0.0  CSB  IN-MARKET-3PD-CONTEXTUAL
# 73769                           8656.3  B2B   CATEGORY-3PD-CONTEXTUAL
# 73771                              0.0  B2B     RETARGET-1PD-RETARGET
# 73772                              0.0  CSB               CONQUESTING
# 73773                              0.0  CSB     RETARGET-1PD-RETARGET
#
# [5 rows x 24 columns]

# %%
df_filter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 235706 entries, 73768 to 365252
# Data columns (total 24 columns):
#  #   Column                            Non-Null Count   Dtype
# ---  ------                            --------------   -----
#  0   Data Stream Parent Stream         232953 non-null  object
#  1   Global Country (Calc)             235706 non-null  object
#  2   Global Region (Calc)              235706 non-null  object
#  3   Display Business Unit Mapped      235706 non-null  object
#  4   Global Audience Type (Calc)       235706 non-null  object
#  5   Campaign Name                     235706 non-null  object
#  6   Display Funnel Mapped             235706 non-null  object
#  7   Display Dell Vehicle Mapped       235706 non-null  object
#  8   Display Site Name Mapped          235672 non-null  object
#  9   Dell Fiscal Quarter Week          235706 non-null  object
#  10  Dell Fiscal Week                  235706 non-null  object
#  11  Dell Fiscal Quarter               235706 non-null  object
#  12  Dell Fiscal Month                 235706 non-null  object
#  13  Campaign Advertiser               232953 non-null  object
#  14  Campaign Advertiser ID            232952 non-null  float64
#  15  Media Buy Name                    235706 non-null  object
#  16  Campaign Status                   0 non-null       float64
#  17  Global Tactic (Calc)              235706 non-null  object
#  18  Global Tactic CSB (Calc)          235706 non-null  object
#  19  Global Tactic V2 B2B (Calc)       206979 non-null  object
#  20  Actual Spend (GCSB) (Calc)        235706 non-null  float64
#  21  LC True Revenue BQ (GCSB) (Calc)  235706 non-null  float64
#  22  LOB                               235706 non-null  object
#  23  Audience Type                     230397 non-null  object
# dtypes: float64(4), object(20)
# memory usage: 45.0+ MB

# %% [markdown]
# ### Data Export

# %%
df_group = df_filter.groupby(['Global Country (Calc)',
                                'Global Audience Type (Calc)',
                                'Display Funnel Mapped',
                                'Global Tactic V2 B2B (Calc)',
                                'LOB',
                                'Audience Type',])[['Actual Spend (GCSB) (Calc)','LC True Revenue BQ (GCSB) (Calc)']].sum()

# %%
df_group.to_csv('csv/Audience_Type_Report_Delve_Spend_&_Revenue_US.csv')
