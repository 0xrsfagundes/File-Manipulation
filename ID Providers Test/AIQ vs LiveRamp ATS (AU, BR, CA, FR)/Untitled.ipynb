# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv(r'csv\df.csv', parse_dates=['Date'])

# %%
df.head()
# Out:
#         Date  \
# 0 2023-08-12
# 1 2023-08-12
# 2 2023-08-12
# 3 2023-08-12
# 4 2023-08-13
#
#                                                                                                               Placement  \
# 0  DV360_CRM-1PD CRM_STANDARD BANNER_160x600_DCPM_INTEL CCF_STD_FY24Q3_d14s5u5pfra-test-reactfullaiqv2-1pcrm_FR CSB_AIQ
# 1  DV360_CRM-1PD CRM_STANDARD BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_d14s5u5pfra-test-reactfullaiqv2-1pcrm_FR CSB_AIQ
# 2  DV360_CRM-1PD CRM_STANDARD BANNER_300x600_DCPM_INTEL CCF_STD_FY24Q3_d14s5u5pfra-test-reactfullaiqv2-1pcrm_FR CSB_AIQ
# 3   DV360_CRM-1PD CRM_STANDARD BANNER_728x90_DCPM_INTEL CCF_STD_FY24Q3_d14s5u5pfra-test-reactfullaiqv2-1pcrm_FR CSB_AIQ
# 4  DV360_CRM-1PD CRM_STANDARD BANNER_160x600_DCPM_INTEL CCF_STD_FY24Q3_d14s5u5pfra-test-reactfullaiqv2-1pcrm_FR CSB_AIQ
#
#    Impressions  Clicks  Reach  Frequency  Audience ID Country  Number Provider
# 0         20.0     0.0    0.0       0.00  d14s5u5pfra      FR       2      AIQ
# 1        643.0     0.0  173.0       3.72  d14s5u5pfra      FR       2      AIQ
# 2        117.0     0.0    0.0       0.00  d14s5u5pfra      FR       2      AIQ
# 3        108.0     0.0    0.0       0.00  d14s5u5pfra      FR       2      AIQ
# 4         54.0     0.0    0.0       0.00  d14s5u5pfra      FR       2      AIQ

# %%
grouped_df = df.groupby(['Country','Provider'])[['Impressions','Clicks']].sum().reset_index()

grouped_df.fillna(0, inplace=True)

# %%
grouped_df.pivot(index=['Country'], columns='Provider').style.format("{:,.0f}")
# Out:
# <style type="text/css">
# </style>
# <table id="T_6f9e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f9e5_level0_col0" class="col_heading level0 col0" colspan="2">Impressions</th>
#       <th id="T_6f9e5_level0_col2" class="col_heading level0 col2" colspan="2">Clicks</th>
#     </tr>
#     <tr>
#       <th class="index_name level1" >Provider</th>
#       <th id="T_6f9e5_level1_col0" class="col_heading level1 col0" >AIQ</th>
#       <th id="T_6f9e5_level1_col1" class="col_heading level1 col1" >LR</th>
#       <th id="T_6f9e5_level1_col2" class="col_heading level1 col2" >AIQ</th>
#       <th id="T_6f9e5_level1_col3" class="col_heading level1 col3" >LR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Country</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f9e5_level0_row0" class="row_heading level0 row0" >AU</th>
#       <td id="T_6f9e5_row0_col0" class="data row0 col0" >239,833</td>
#       <td id="T_6f9e5_row0_col1" class="data row0 col1" >48,188</td>
#       <td id="T_6f9e5_row0_col2" class="data row0 col2" >218</td>
#       <td id="T_6f9e5_row0_col3" class="data row0 col3" >25</td>
#     </tr>
#     <tr>
#       <th id="T_6f9e5_level0_row1" class="row_heading level0 row1" >BR</th>
#       <td id="T_6f9e5_row1_col0" class="data row1 col0" >2,916,035</td>
#       <td id="T_6f9e5_row1_col1" class="data row1 col1" >11,664,672</td>
#       <td id="T_6f9e5_row1_col2" class="data row1 col2" >2,750</td>
#       <td id="T_6f9e5_row1_col3" class="data row1 col3" >66,635</td>
#     </tr>
#     <tr>
#       <th id="T_6f9e5_level0_row2" class="row_heading level0 row2" >CA</th>
#       <td id="T_6f9e5_row2_col0" class="data row2 col0" >576,752</td>
#       <td id="T_6f9e5_row2_col1" class="data row2 col1" >102,894</td>
#       <td id="T_6f9e5_row2_col2" class="data row2 col2" >222</td>
#       <td id="T_6f9e5_row2_col3" class="data row2 col3" >42</td>
#     </tr>
#     <tr>
#       <th id="T_6f9e5_level0_row3" class="row_heading level0 row3" >FR</th>
#       <td id="T_6f9e5_row3_col0" class="data row3 col0" >681,798</td>
#       <td id="T_6f9e5_row3_col1" class="data row3 col1" >nan</td>
#       <td id="T_6f9e5_row3_col2" class="data row3 col2" >3,027</td>
#       <td id="T_6f9e5_row3_col3" class="data row3 col3" >nan</td>
#     </tr>
#   </tbody>
# </table>
