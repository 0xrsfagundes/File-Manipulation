# %% [markdown]
# <h1>Data Providers Analysis (SFAS & Neustar)</h1>
#
# <ul>
# <li>180byTwo</li>
# <li>33Across</li>
# <li>AdAdvisor - Age</li>
# <li>AdAdvisor - Business</li>
# <li>AdAdvisor - Consumer</li>
# <li>AdAdvisor - ElementOne</li>
# <li>AdAdvisor - Financial</li>
# <li>AdAdvisor - Gender</li>
# <li>AdAdvisor - Household</li>
# <li>AnalyticsIQ</li>
# <li>Clickagy</li>
# <li>Comscore OTT Audiences</li>
# <li>Comscore TV Audiences</li>
# <li>Comscore TV Event Audiences</li>
# <li>Equifax</li>
# <li>Factual</li>
# <li>Lotame</li>
# <li>Startio</li>
# <li>Webbula</li>
# <li>Neustar Site Activities</li>
# </ul>

# %%
import pandas as pd
import warnings
import numpy as np

warnings.filterwarnings('ignore')

# %% [markdown]
# ### SFAS Taxonomies

# %%
df_sfas = pd.read_csv(r'C:\Users\rafael_fagundes\OneDrive - Dell Technologies\Documents\DB\TB_BILLING_DATA_NA.csv')

# %%
df_sfas.head()
# Out:
#        Org BillingReportDate  OrgID  \
# 0  Dell NA           2020-03   4410
# 1  Dell NA           2020-03   4410
# 2  Dell NA           2020-03   4410
# 3  Dell NA           2020-03   4410
# 4  Dell NA           2020-03   4410
#
#                                    CoreSegment CoreSegmentID    Partner  \
# 0  bargain shoppers_us-consumer_3p_acxiom_1x90     us2cpbpb2  MediaMath
# 1  smart tech sb shopers_us-sb_3p_neustar_1x90     us92mfavz  MediaMath
# 2  smart tech sb shopers_us-sb_3p_neustar_1x90     us92mfavz  MediaMath
# 3  smart tech sb shopers_us-sb_3p_neustar_1x90     us92mfavz  MediaMath
# 4  smart tech sb shopers_us-sb_3p_neustar_1x90     us92mfavz  MediaMath
#
#    CoreSegmentImpressions  OrderCode                        Provider  \
# 0                  367813        NaN                          Acxiom
# 1                  460772        NaN  AdAdvisor Audiences by Neustar
# 2                  460772        NaN  AdAdvisor Audiences by Neustar
# 3                  460772        NaN  AdAdvisor Audiences by Neustar
# 4                  460772        NaN  AdAdvisor Audiences by Neustar
#
#                            ProviderUUID                 ProviderSegment  \
# 0  f19b7626-3732-4dcc-bac5-8d2c937dae9a                Bargain Shoppers
# 1  2111c0af-fc3a-446f-ab07-63aa74fbde8e        Company Size: 1 employee
# 2  2111c0af-fc3a-446f-ab07-63aa74fbde8e     Company Size: 1-4 employees
# 3  2111c0af-fc3a-446f-ab07-63aa74fbde8e  Company Size: 20-100 employees
# 4  2111c0af-fc3a-446f-ab07-63aa74fbde8e    Company Size: 5-19 employees
#
#   ProviderSegmentCode DataProviderSegmentID  CPM PriceModel SalesforceBilled  \
# 0           300730999              K-rUmWrc  1.0        CPM                Y
# 1              906697              JdXW-jSC  1.5        CPM                Y
# 2              906695              JdXW-hOh  1.5        CPM                Y
# 3              906696              JdXW-iNl  1.5        CPM                Y
# 4               18392              KKO0_J3T  1.5        CPM                Y
#
#    Impressions  Cost UsageDate ProviderType
# 0         6712  6.71   2020-02          3rd
# 1           87  0.13   2020-02          3rd
# 2          590  0.89   2020-02          3rd
# 3          119  0.18   2020-02          3rd
# 4          467  0.70   2020-02          3rd

# %%
df_sfas_export = df_sfas[['Provider','ProviderSegment']].value_counts().reset_index()

# %%
df_sfas_export.to_html('csv/df_sfas_export.html')

# %% [markdown]
# ### Neustar Taxonomies

# %%
df_ns_taxonomies = pd.read_csv(r'C:\Users\rafael_fagundes\OneDrive - Dell Technologies\Documents\DB\Dell_Dell_Data_providers_2023-05-31.csv')

# %%
df_ns_taxonomies.head()
# Out:
#   Data Provider           Taxonomy Name  Attribute ID  \
# 0      180byTWO  180byTwo_DataDirectory      30866358
# 1      180byTWO  180byTwo_DataDirectory      30866364
# 2      180byTWO  180byTwo_DataDirectory      30866365
# 3      180byTWO  180byTwo_DataDirectory      30866373
# 4      180byTWO  180byTwo_DataDirectory      30866374
#
#                                       Attribute Name Category   HH  HH Plus  \
# 0  180byTwo from Anteriad > ABM > Top Companies >...      ABM  544      676
# 1  180byTwo from Anteriad > ABM > Top Companies >...      ABM  927     1172
# 2  180byTwo from Anteriad > ABM > Top Companies >...      ABM   12       14
# 3  180byTwo from Anteriad > ABM > Top Companies >...      ABM  108      141
# 4  180byTwo from Anteriad > ABM > Top Companies >...      ABM  199      253
#
#     IND  IND Plus   CPM                                        Description  \
# 0   697       829  2.25  Audience is comprised of individuals are known...
# 1  1360      1605  2.25  Audience is comprised of individuals are known...
# 2    14        16  2.25  Audience is comprised of individuals who are k...
# 3   126       159  2.25  Audience is comprised of individuals who are k...
# 4   280       334  2.25  Audience is comprised of individuals are known...
#
#   Source Restrictions
# 0    NaN          NaN
# 1    NaN          NaN
# 2    NaN          NaN
# 3    NaN          NaN
# 4    NaN          NaN

# %%
export = df_ns_taxonomies[['Taxonomy Name','Attribute Name', 'Category', 'HH','HH Plus', 'IND Plus','IND','CPM']]

export[['lvl1', 'lvl2','lvl3','lvl4','lvl5', 'lvl6', 'lvl7', 'lvl8']] = export['Attribute Name'].str.split('>', expand=True, n=7)
# Out:
# C:\Users\rafael_fagundes\AppData\Local\Temp\ipykernel_46280\1652562565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export[['lvl1', 'lvl2','lvl3','lvl4','lvl5', 'lvl6', 'lvl7', 'lvl8']] = export['Attribute Name'].str.split('>', expand=True, n=7)
# C:\Users\rafael_fagundes\AppData\Local\Temp\ipykernel_46280\1652562565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export[['lvl1', 'lvl2','lvl3','lvl4','lvl5', 'lvl6', 'lvl7', 'lvl8']] = export['Attribute Name'].str.split('>', expand=True, n=7)
# C:\Users\rafael_fagundes\AppData\Local\Temp\ipykernel_46280\1652562565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export[['lvl1', 'lvl2','lvl3','lvl4','lvl5', 'lvl6', 'lvl7', 'lvl8']] = export['Attribute Name'].str.split('>', expand=True, n=7)
# C:\Users\rafael_fagundes\AppData\Local\Temp\ipykernel_46280\1652562565.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   export[['lvl1', 'lvl2','lvl3','lvl4','lvl5', 'lvl6', 'lvl7', 'lvl8']] = export['Attribute Name'].str.split('>', expand=True, n=7)

# %%
data_providers = '(180bytwo|33across|adadvisor|analyticsiq|clickagy|comscore|equifax|factual|lotame|startio|webbula)'

export['Data Provider'] = export['Taxonomy Name'].str.lower().str.extract(data_providers)

# %%
export[~export['Data Provider'].isnull()].to_csv('csv/df_ns_taxonomies.csv')

# %% [markdown]
# ### Neustar Audiences

# %%
df_ns_audiences = pd.read_csv(r'C:\Users\rafael_fagundes\OneDrive - Dell Technologies\Documents\DB\audiences_for_Dell_17407_.csv')

# %%
df_ns_audiences.head()
# Out:
#    Advertiser_Id Advertiser_Name  Audience_Id  \
# 0          17407            Dell     46485037
# 1          17407            Dell     46485035
# 2          17407            Dell     46485036
# 3          17407            Dell     46485034
# 4          17407            Dell     46485033
#
#                                        Audience_Name  \
# 0  targeting-dellpurchaseintent_us-csbo-con_3poff...
# 1  targeting-restaurants_us-csbo-sb_3pofftheshelf...
# 2  targeting-accountants_us-csbo-sb_3pofftheshelf...
# 3  targeting-architects_us-csbo-sb_3pofftheshelf_...
# 4  targeting-tvlovers_us-csbo-sb_3pofftheshelf_ne...
#
#                                  Audience_Expression Match_Level     Unique  \
# 0  ([12894/*Neustar AdAdvisor Consumer Audiences*...  INDIVIDUAL  143553658
# 1  ([12894/*Neustar AdAdvisor Consumer Audiences*...  INDIVIDUAL   48425370
# 2  ([12894/*Neustar AdAdvisor Consumer Audiences*...  INDIVIDUAL   49778603
# 3  ([12894/*Neustar AdAdvisor Consumer Audiences*...  INDIVIDUAL  119934688
# 4  ([12894/*Neustar AdAdvisor Consumer Audiences*...  INDIVIDUAL   52017056
#
#    CPM
# 0  1.0
# 1  1.0
# 2  1.5
# 3  2.5
# 4  1.0

# %%
pd.set_option('max_colwidth', None)

df_ns_audiences['Audience_Expression'].to_frame(all)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       <built-in function all>
# 0                                                                                                                                                                                                                                                                                                                                     ([12894/*Neustar AdAdvisor Consumer Audiences*/,2997575/*Technology & Computing > Computer Brand > Home PC-Brand HH Most Recently Acquired-Dell*/]||[33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,4947864/*Owns Dell Computer*/])
# 1                                                                                                     ([12894/*Neustar AdAdvisor Consumer Audiences*/,2997252/*Restaurants > Family Restaurant & Steak House > Family Restaurant-Most Last 30D-Olive Garden*/]||[12894/*Neustar AdAdvisor Consumer Audiences*/,2997253/*Restaurants > Family Restaurant & Steak House > Family Restaurant-Most Last 30D-Outback Steakhouse*/]||[12894/*Neustar AdAdvisor Consumer Audiences*/,2997245/*Restaurants > Family Restaurant & Steak House > Family Restaurant-Most Last 30D-Cheesecake Factory*/])
# 2                                                                                                                                                                                                             ([12894/*Neustar AdAdvisor Consumer Audiences*/,2997131/*Personal Finance > Banking > Banking/Investments: Have Savings Account(s)*/]||[12160/*Neustar AdAdvisor - Business*/,2965188/*Finance, Insurance, and Accounting*/]||[12894/*Neustar AdAdvisor Consumer Audiences*/,2997129/*Personal Finance > Banking > Banking/Investments: Have Interest Bearing Check Account*/])
# 3   ([12894/*Neustar AdAdvisor Consumer Audiences*/,6919426/*Demographics > Occupation > Occupation: Professional- Architecture & Engineering/Life*/]||[33281/*Neustar AdAdvisor Identity Planner Audiences - Business*/,4949642/*Architects*/]||[33282/*Neustar AdAdvisor Identity Planner Audiences - Demographic*/,40548194/*Household Occupations | Household Member Occupation Group | Technical:Computers/Math and Architect/Engineering*/]||[33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,4947214/*Occupation: Professional- Architecture & Engineering/Life*/])
# 4                                                                                                                                                                                                                                                                                                    ([12894/*Neustar AdAdvisor Consumer Audiences*/,6919386/*Computers & Electronics > TV - When Acquired > HH Acquired Any TV 3-4 Years Ago*/]||[12894/*Neustar AdAdvisor Consumer Audiences*/,6919388/*Computers & Electronics > TV - When Acquired > HH Acquired Any TV 1-2 Years Ago*/])
# ..                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ...
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              ([44/*US States & Canadian Provinces*/,259104/*CALIFORNIA*/])
# 66                                                                                                                                                                                                                                                                                                                                                                                            ([37656/*Clickagy Public Taxonomy*/,20946441/*In-Market > Electronics > Computers > Desktops*/]||[37656/*Clickagy Public Taxonomy*/,20946444/*In-Market > Electronics > Computers > Laptops*/])
# 67                                                                                                                                                                                                                                                                                                                                                            ([33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,4947871/*Last Computer Purchase: 2-3 Years Ago*/])&&!([33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,4947862/*Owns Apple Computer*/])
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 ([36489/*Dell*/,45101641/*Test Segment*/])
# 69                                                                                                                                                                                                                                                                                                      ([12160/*Neustar AdAdvisor - Business*/,2965213/*Small office or Home office Business Owners*/]||[12160/*Neustar AdAdvisor - Business*/,2965252/*SOHO 2- Real Estate Services*/]||[12160/*Neustar AdAdvisor - Business*/,2965274/*SOHO 25- Small Office Or Home Office Businesses*/])
#
# [70 rows x 1 columns]

# %%
pattern1 = r'\[(.*?)\]'
extracted_items1 = df_ns_audiences['Audience_Expression'].astype(str).str.extractall(pattern1)[0]

df_taxonomies = pd.DataFrame(extracted_items1.value_counts()).reset_index()

df_taxonomies.rename(columns={'index':'Taxonomy', 0:'Count'}, inplace=True)

#pattern2 = r'\*(.*?)\*' # Regular expression pattern to match items between double asterisks
#df_taxonomies['index'] = df_taxonomies['index'].str.replace(pattern2, '')

# %%
df_taxonomies[['lvl1','lvl2','lvl3','lvl4','lvl5','lvl6','lvl7','lvl8']] = df_taxonomies['Taxonomy'].str.split('[>/]',expand=True, n=7)

df_taxonomies.head()
# Out:
#                                                                                                                          Taxonomy  \
# 0                      33281/*Neustar AdAdvisor Identity Planner Audiences - Business*/,4949607/*Company Size: 20-100 employees*/
# 1                                33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,4947864/*Owns Dell Computer*/
# 2                         33281/*Neustar AdAdvisor Identity Planner Audiences - Business*/,4949606/*Company Size: 1-4 employees*/
# 3       25752/*180byTwo_DataDirectory*/,30867475/*180byTwo from Anteriad > B2B > Company Classifications > Small Business / SMB*/
# 4  33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,40451405/*Use Laptop/Notebook/Netbook for Home Automation*/
#
#    Count DataProvider   lvl1  \
# 0      5    adadvisor  33281
# 1      4    adadvisor  33466
# 2      4    adadvisor  33281
# 3      4     180bytwo  25752
# 4      3    adadvisor  33466
#
#                                                           lvl2       lvl3  \
# 0    *Neustar AdAdvisor Identity Planner Audiences - Business*   ,4949607
# 1  *Neustar AdAdvisor Identity Planner Audiences - Propensity*   ,4947864
# 2    *Neustar AdAdvisor Identity Planner Audiences - Business*   ,4949606
# 3                                     *180byTwo_DataDirectory*  ,30867475
# 4  *Neustar AdAdvisor Identity Planner Audiences - Propensity*  ,40451405
#
#                                lvl4      lvl5                          lvl6  \
# 0  *Company Size: 20-100 employees*                                    None
# 1              *Owns Dell Computer*                                    None
# 2     *Company Size: 1-4 employees*                                    None
# 3          *180byTwo from Anteriad       B2B       Company Classifications
# 4                       *Use Laptop  Notebook  Netbook for Home Automation*
#
#                lvl7    lvl8
# 0              None    None
# 1              None    None
# 2              None    None
# 3   Small Business    SMB*/
# 4                      None

# %%
data_providers = '(180bytwo|33across|adadvisor|analyticsiq|clickagy|comscore|equifax|factual|lotame|startio|webbula)'

df_taxonomies['DataProvider'] = df_taxonomies['Taxonomy'].str.lower().str.extract(data_providers)

# %%
df_taxonomies.head()
# Out:
#                                                                                                                          Taxonomy  \
# 0                      33281/*Neustar AdAdvisor Identity Planner Audiences - Business*/,4949607/*Company Size: 20-100 employees*/
# 1                                33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,4947864/*Owns Dell Computer*/
# 2                         33281/*Neustar AdAdvisor Identity Planner Audiences - Business*/,4949606/*Company Size: 1-4 employees*/
# 3       25752/*180byTwo_DataDirectory*/,30867475/*180byTwo from Anteriad > B2B > Company Classifications > Small Business / SMB*/
# 4  33466/*Neustar AdAdvisor Identity Planner Audiences - Propensity*/,40451405/*Use Laptop/Notebook/Netbook for Home Automation*/
#
#    Count DataProvider   lvl1  \
# 0      5    adadvisor  33281
# 1      4    adadvisor  33466
# 2      4    adadvisor  33281
# 3      4     180bytwo  25752
# 4      3    adadvisor  33466
#
#                                                           lvl2       lvl3  \
# 0    *Neustar AdAdvisor Identity Planner Audiences - Business*   ,4949607
# 1  *Neustar AdAdvisor Identity Planner Audiences - Propensity*   ,4947864
# 2    *Neustar AdAdvisor Identity Planner Audiences - Business*   ,4949606
# 3                                     *180byTwo_DataDirectory*  ,30867475
# 4  *Neustar AdAdvisor Identity Planner Audiences - Propensity*  ,40451405
#
#                                lvl4      lvl5                          lvl6  \
# 0  *Company Size: 20-100 employees*                                    None
# 1              *Owns Dell Computer*                                    None
# 2     *Company Size: 1-4 employees*                                    None
# 3          *180byTwo from Anteriad       B2B       Company Classifications
# 4                       *Use Laptop  Notebook  Netbook for Home Automation*
#
#                lvl7    lvl8
# 0              None    None
# 1              None    None
# 2              None    None
# 3   Small Business    SMB*/
# 4                      None

# %%
df_taxonomies.to_csv('csv/df_ns_audiences.csv')
