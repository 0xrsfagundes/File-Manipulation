# %%
import pandas as pd
import warnings

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r'C:\Users\Rafael_Fagundes\Downloads\1153793_Lotame__LiveRamp__AIQ_test_-_AU_BR_CA__FR_20230815_064016_4239885799.csv', skiprows=10,skipfooter=1, parse_dates=['Date'])

# %%
df.head()
# Out:
#      Advertiser                          Campaign  Campaign ID Site (CM360)  \
# 0  Alienware_CA  2021_Q1_CA_AW_MF_SOCIAL_FACEBOOK     23773590     Facebook
# 1  Alienware_CA  2021_Q2_CA_AW_MF_DISPLAY_DESKTOP     24082257     Outbrain
# 2  Alienware_CA  2021_Q2_CA_AW_MF_DISPLAY_DESKTOP     24082257     Outbrain
# 3  Alienware_CA  2021_Q2_CA_AW_MF_DISPLAY_DESKTOP     24082257     Outbrain
# 4  Alienware_CA  2021_Q2_CA_AW_MF_DISPLAY_DESKTOP     24082257     Outbrain
#
#                                                                          Placement  \
# 0              FACEBOOK_LAL_HTML5_1x1_DCPM_DELL_CT_FY21Q1_AW MF MOBILE_ IG CRM LAL
# 1  OUTBRAIN_PROSPECT_NATIVE_1x1_DCPM_DELL_CT_FY21Q2_DESKTOP NON DCO AW_Prospecting
# 2  OUTBRAIN_PROSPECT_NATIVE_1x1_DCPM_DELL_CT_FY21Q2_DESKTOP NON DCO AW_Prospecting
# 3  OUTBRAIN_PROSPECT_NATIVE_1x1_DCPM_DELL_CT_FY21Q2_DESKTOP NON DCO AW_Prospecting
# 4  OUTBRAIN_PROSPECT_NATIVE_1x1_DCPM_DELL_CT_FY21Q2_DESKTOP NON DCO AW_Prospecting
#
# ...

# %%
audience_codes = '(dgfrrpdw7ov|d2q11zclsgv|duxo79h5t8o|dkgud3s0umw|dwm57ismy2g|d3ok01g6usv|dv7sm9mltvm|d7qd2wu3gkb|dw1v0i89ctr|d6m18ot8p0w|d14s5u5pfra)'

df_filtered = df[df['Placement'].str.contains(audience_codes, case=False, regex=True)]

# %%
df_filtered
# Out:
#                         Advertiser  \
# 716511  Consumer Small Business_FR
# 716512  Consumer Small Business_FR
# 716513  Consumer Small Business_FR
# 716514  Consumer Small Business_FR
# 716515  Consumer Small Business_FR
# 716516  Consumer Small Business_FR
# 716517  Consumer Small Business_FR
# 716518  Consumer Small Business_FR
# 716519  Consumer Small Business_FR
# 716520  Consumer Small Business_FR
# 716521  Consumer Small Business_FR
# 716522  Consumer Small Business_FR
#
#                                                Campaign  Campaign ID  \
# 716511  2024_Q3_FR_CSBO-CSB_BSP_DISPLAY_RETARGETING_CSB     30433086
# 716512  2024_Q3_FR_CSBO-CSB_BSP_DISPLAY_RETARGETING_CSB     30433086
# 716513  2024_Q3_FR_CSBO-CSB_BSP_DISPLAY_RETARGETING_CSB     30433086
# 716514  2024_Q3_FR_CSBO-CSB_BSP_DISPLAY_RETARGETING_CSB     30433086
# 716515  2024_Q3_FR_CSBO-CSB_BSP_DISPLAY_RETARGETING_CSB     30433086
# 716516  2024_Q3_FR_CSBO-CSB_BSP_DISPLAY_RETARGETING_CSB     30433086
# ...
