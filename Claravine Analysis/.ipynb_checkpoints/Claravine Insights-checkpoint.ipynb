# %%
import pandas as pd
import warnings

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %%
folder_path = r'..\..\Dell-Projects\Helper\Claravine.csv'

df = pd.read_csv(folder_path, parse_dates=['created_date'])

# %%
df.head()
# Out:
#     Segment ID  \
# 0   14o04dsyat
# 1  da2z3jfdx3d
# 2  d2l072rynmf
# 3  dztqn3bkuwh
# 4  dfmb6iq56n5
#
#                                                                                                                                        Dell Audience Name  \
# 0                                                                                                                                                     NaN
# 1                                                                                                                                                     NaN
# 2                                                                                       targeting-development-development_us-csbo-csb_1pcrm-aiqcrm-cip_na
# 3  targeting-development/highdellpropensity/highgamingpropensity/highvaluehousehold/notreact/pcpurchaseflag-gamingpcbuyer_us-csbo-csb_1pcrm-aiqcrm-cip_na
# 4                                                                                    targeting-im/mb-mbinmarket_us-mb_abm-liveramp-dunandbradstreet_fi/im
#
#                                                                                                                                    VAR Dell Audience Name  \
# 0                                                                                                                                                     NaN
# 1                                                                                                                                                     NaN
# 2                                                                                       targeting-development-development_us-csbo-csb_1pcrm-aiqcrm-cip_na
# 3  targeting-development/highdellpropensity/highgamingpropensity/highvaluehousehold/notreact/pcpurchaseflag-gamingpcbuyer_us-csbo-csb_1pcrm-aiqcrm-cip_na
# 4                                                                                    targeting-im/mb-mbinmarket_us-mb_abm-liveramp-dunandbradstreet_fi/im
#
#                                                                                                                            Dell Audience Name concatenation  \
# 0                                                          Seed LAL-gamer-test-provider-MAID+Cookies_us-csbo-aw_Google Analytics-Oracle Data Marketplace_IN
# 1                                                                            3P Data enrichment-inquirer-test_us-csbo-csb_Google Analytics-Bombora_DE-FI-IM
# 2                                                                                       Targeting-development-development_us-csbo-csb_1p CRM-AIQ CRM-CIP_NA
# 3  Targeting-development/highdellpropensity/highgamingpropensity/highvaluehousehold/notreact/pcpurchaseflag-gamingpcbuyer_us-csbo-csb_1p CRM-AIQ CRM-CIP_NA
# 4                                                                                    Targeting-im/mb-mbinmarket_us-mb_abm-Liveramp-Dun and Bradstreet_FI/IM
#
#                                            MediaCom Audience Name  \
# 0                                                             NaN
# 1                                                             NaN
# 2           targeting-development_us-csbo-csb_1pcrm-aiqcrm-cip_na
# 3         targeting-gamingpcbuyer_us-csbo-csb_1pcrm-aiqcrm-cip_na
# 4  targeting-mbinmarket_us-mb_abm-liveramp-dunandbradstreet_fi/im
#
#                                MediaCom Audience Name Concatenation  \
# 0                                                               NaN
# 1                                                               NaN
# 2           Targeting-development_us-csbo-csb_1p CRM-AIQ CRM-CIP_NA
# 3         Targeting-gamingpcbuyer_us-csbo-csb_1p CRM-AIQ CRM-CIP_NA
# 4  Targeting-mbinmarket_us-mb_abm-Liveramp-Dun and Bradstreet_FI/IM
#
#    Audience Objective  \
# 0            Seed LAL
# 1  3P Data enrichment
# 2           Targeting
# 3           Targeting
# 4           Targeting
#
#                                                                                  Seed Information  \
# 0                                                                             gamer-test-provider
# 1                                                                                        inquirer
# 2                                                                                     development
# 3  development/highdellpropensity/highgamingpropensity/highvaluehousehold/notreact/pcpurchaseflag
# 4                                                                                           im/mb
#
#   Audience Composition  \
# 0         MAID+Cookies
# 1                 test
# 2          development
# 3        gamingpcbuyer
# 4           mbinmarket
#
#                                                                                        Audience Composition concatenation  \
# 0                                                                               Seed LAL-gamer-test-provider-MAID+Cookies
# 1                                                                                        3P Data enrichment-inquirer-test
# 2                                                                                       Targeting-development-development
# 3  Targeting-development/highdellpropensity/highgamingpropensity/highvaluehousehold/notreact/pcpurchaseflag-gamingpcbuyer
# 4                                                                                              Targeting-im/mb-mbinmarket
#
#   Audience Object-Audience Composition Country Business Unit  \
# 0                                  NaN      us       csbo-aw
# 1                                  NaN      us      csbo-csb
# 2                Targeting-development      us      csbo-csb
# 3              Targeting-gamingpcbuyer      us      csbo-csb
# 4                 Targeting-mbinmarket      us            mb
#
#   Country-BU concatenation Data Type   Audience Source Data Provider  \
# 0               us-csbo-aw  1p Pixel  Google Analytics           NaN
# 1              us-csbo-csb  1p Pixel  Google Analytics           NaN
# 2              us-csbo-csb    1p CRM           AIQ CRM           NaN
# 3              us-csbo-csb    1p CRM           AIQ CRM           NaN
# 4                    us-mb       abm          Liveramp           NaN
#
#   Data Provider Abbreviation Audience Source-Data Provider concatenation  \
# 0    Oracle Data Marketplace    Google Analytics-Oracle Data Marketplace
# 1                    Bombora                    Google Analytics-Bombora
# 2                        CIP                          1p CRM-AIQ CRM-CIP
# 3                        CIP                          1p CRM-AIQ CRM-CIP
# 4         Dun and Bradstreet             abm-Liveramp-Dun and Bradstreet
#
#                    Attribute Category Attribute Category Shortcode  \
# 0                            Interest                           IN
# 1  Demographic-Firmographic-In Market                     DE-FI-IM
# 2                                 NaN                          NaN
# 3                                 NaN                          NaN
# 4              Firmographic/In Market                        FI/IM
#
#   Audience Category Reporting Platform      Random Prefix  \
# 0    CTV-3PD RETARGET EXPOSED      NaN  14o04dsyat      d
# 1                 CRM-1PD AIQ      NaN  a2z3jfdx3d      d
# 2                 CRM-1PD AIQ      NaN  2l072rynmf      d
# 3                 CRM-1PD AIQ      NaN  ztqn3bkuwh      d
# 4            DMP-3PD AUDIENCE      NaN  fmb6iq56n5      d
#
#                          Claravine ID submission_name         submitter_name  \
# 0  CV05f91b67fa57425e8e08d7c41509eabb    List Starter         Rebekah Garner
# 1  CV8b1fb1a5c12f414a914b11b320162f43    1/19/23 Demo  Rebekah Garner (User)
# 2  CV418260be4c9843e3bdbe2e68a65d0ed3   stress test 1          Enrique Leigh
# 3  CVea58ace9f72e4bb89c09b5824e90c1d7   stress test 1          Enrique Leigh
# 4  CVd9aa47f906f147c9acad1691b2cc9f75        ABM Test          Enrique Leigh
#
#          created_date
# 0 2023-01-17 18:56:46
# 1 2023-01-19 14:45:00
# 2 2023-01-20 17:49:12
# 3 2023-01-20 17:49:12
# 4 2023-01-23 20:09:10

# %%
grouped_df = df.groupby(['Country','Business Unit'])['Segment ID'].count().reset_index()

# %%
grouped_df
# Out:
#    Country Business Unit  Segment ID
# 0      apj           b2b           1
# 1      apj      pan-dell           1
# 2       au       B2B-COM           4
# 3       au        B2B-MB           4
# 4       au           b2b           2
# ..     ...           ...         ...
# 77      us      csbo-con         124
# 78      us      csbo-csb          19
# 79      us  csbo-gseries          38
# 80      us       csbo-sb         110
# 81      us            mb          66
#
# [82 rows x 3 columns]
