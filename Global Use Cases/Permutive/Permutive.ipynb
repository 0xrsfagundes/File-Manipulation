# %%
import warnings
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %%
folder_path = r'C:\Users\Rafael_Fagundes\Downloads\compiled_data.csv'

df = pd.read_csv(folder_path)

# %%
campaign_list = ['2024_Q2_US_CSBO-CON_AP_DISPLAY_PROSPECTING_NA'
                ,'2024_Q2_CA_CSBO-CON_AP_DISPLAY-DCO_PROSPECTING_DESKTOP DV360 Permutive'
                ,'2024_Q2_UK_CSBO-CSB_AP_DISPLAY_PROSPECTING_CSB'
                ,'2024_Q2_US_CSBO-CON_AP_DISPLAY_PROSPECTING_NA'
                ,'2024_Q2_US_CSBO-CON_HP_DISPLAY_BRAND_NA'
                ,'2024_Q3_US_CSBO-CON_AP_DISPLAY_PROSPECTING_NA'
                ,'2024_Q3_CA_CSBO-CON_AP_DISPLAY-DCO_PROSPECTING_DESKTOP DV360 Permutive'
                ,'2024_Q3_UK_CSBO-CSB_AP_DISPLAY_PROSPECTING_CSB'
                ,'2024_Q3_US_CSBO-CON_AP_DISPLAY_PROSPECTING_NA'
                ,'2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA'
                ]

# %%
filtered_df = df[df['Campaign Name'].isin(campaign_list)]

# %%
filtered_df['Permutive'] = df['Media Buy Name'].apply(lambda x: 'Permutive' if 'Permutive' in x else '')

# %%
filtered_df[filtered_df['Media Buy Name'].str.contains('Permutive')].head()
# Out:
#          Unnamed: 0 Audience Type       Tactic  \
# 1262821     1262821           3PD  Prospecting
# 1262822     1262822           3PD  Prospecting
# 1263403     1263403           3PD  Prospecting
# 1263404     1263404           3PD  Prospecting
# 1263405     1263405           3PD  Prospecting
#
#                                                                                                         Media Buy Name  \
# 1262821  DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_160x600_DCPM_INTEL CCF_STD_FY24Q2_NA_Permutive_DISPLAY XPS Millennio
# 1262822    DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_160x600_DCPM_INTEL CCF_STD_FY24Q2_NA_Permutive_DISPLAY XPS Tributo
# 1263403  DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q2_NA_Permutive_DISPLAY XPS Millennio
# 1263404  DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q2_NA_Permutive_DISPLAY XPS Portofino
# ...
