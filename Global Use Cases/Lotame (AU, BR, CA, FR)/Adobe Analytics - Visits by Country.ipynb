# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('csv/Freeform table.csv', date_parser='Day')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 360 entries, 0 to 359
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Country          360 non-null    object
#  1   Day              360 non-null    object
#  2   Visits           360 non-null    int64
#  3   Unique Visitors  360 non-null    int64
#  4   Page Views       360 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 14.2+ KB

# %%
df[df['Country'] == 'Australia'].describe()
# Out:
#              Visits  Unique Visitors     Page Views
# count     90.000000        90.000000      90.000000
# mean   51704.633333     43560.866667  153802.255556
# std    15044.250945     12188.275742   46405.960390
# min    26478.000000     23139.000000   77215.000000
# 25%    40678.000000     35453.250000  123653.750000
# 50%    51873.500000     43185.000000  157273.000000
# 75%    58265.500000     48508.000000  174359.500000
# max    98292.000000     82857.000000  288640.000000

# %%
df[df['Country'] == 'Brazil'].describe()
# Out:
#               Visits  Unique Visitors     Page Views
# count      90.000000        90.000000      90.000000
# mean   253457.622222    208037.466667  724278.355556
# std     60301.298495     47500.890716  193540.241975
# min    138152.000000    115305.000000  383996.000000
# 25%    191166.500000    163838.000000  484170.750000
# 50%    267134.500000    217579.000000  799535.500000
# 75%    295852.000000    240557.750000  873852.750000
# max    381350.000000    314944.000000  987640.000000

# %%
df[df['Country'] == 'Canada'].describe()
# Out:
#               Visits  Unique Visitors     Page Views
# count      90.000000        90.000000      90.000000
# mean    80131.944444     67084.533333  257178.922222
# std     19948.967376     16313.613515   65368.484324
# min     42166.000000     36983.000000  132274.000000
# 25%     58633.000000     50360.750000  185076.500000
# 50%     87738.500000     71756.000000  284399.000000
# 75%     93535.250000     78027.250000  303138.750000
# max    130304.000000    113920.000000  429296.000000

# %%
df[df['Country'] == 'France'].describe()
# Out:
#              Visits  Unique Visitors     Page Views
# count     90.000000        90.000000      90.000000
# mean   29631.722222     23982.522222  107807.444444
# std     9249.738193      7125.023979   33281.616000
# min    14219.000000     11865.000000   51720.000000
# 25%    20370.750000     17008.000000   75589.000000
# 50%    31822.500000     25655.000000  115438.000000
# 75%    37054.750000     29832.250000  132815.250000
# max    45553.000000     36104.000000  170535.000000

# %%
fig = plt.figure(figsize=(10,5))
sns.boxplot(data=df, x='Country', y='Visits')
plt.show()

# %%
fig = plt.figure(figsize=(10,5))
sns.lineplot(data=df,x='Day', y='Visits', hue='Country')
plt.show()
