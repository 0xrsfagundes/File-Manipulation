# %%
import warnings
import pandas as pd
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
warnings.filterwarnings('ignore')

# %% [markdown]
# <h2>Functions</h2>

# %%
def plot_boxplot(data, x_col, y_col, title):
    fig, ax = plt.subplots(figsize=(10, 5))
    ax.set_title(title)
    ax.set_ylabel('ROAS')
    
    sns.boxplot(data=data, x=x_col, y=y_col)
    plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')
    plt.xticks(rotation=90)
    plt.semilogy()

# %% [markdown]
# <h2>Main</h2>

# %%
folder_path = r'C:\Users\Rafael_Fagundes\Downloads\compiled_data_v2.csv'

df = pd.read_csv(folder_path)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1782917 entries, 0 to 1782916
# Data columns (total 49 columns):
#  #   Column                                       Dtype
# ---  ------                                       -----
#  0   Unnamed: 0                                   int64
#  1   Audience Type                                object
#  2   Tactic                                       object
#  3   Media Buy Name                               object
#  4   Campaign Name                                object
#  5   Fiscal Quarter                               object
#  6   Fiscal Week                                  object
#  7   Country_x                                    object
#  8   Display Funnel Mapped                        object
#  9   Display Dell Vehicle Mapped                  object
#  10  Display Business Unit Mapped                 object
#  11  Display Site Name Mapped                     object
#  12  Audience Type Name                           object
#  13  Impressions                                  float64
#  14  Clicks                                       float64
#  15  Spend                                        float64
#  16  Net Rev                                      float64
#  17  HVE                                          float64
#  18  BU                                           object
#  19  Segment ID                                   object
#  20  Audience ID Exists                           object
#  21  Dell Audience Name                           object
#  22  VAR Dell Audience Name                       object
#  23  Dell Audience Name concatenation             object
#  24  MediaCom Audience Name                       object
#  25  MediaCom Audience Name Concatenation         object
#  26  Audience Objective                           object
#  27  Seed Information                             object
#  28  Audience Composition                         object
#  29  Audience Composition concatenation           object
#  30  Audience Object-Audience Composition         object
#  31  Country_y                                    object
#  32  Business Unit                                object
#  33  Country-BU concatenation                     object
#  34  Data Type                                    object
#  35  Audience Source                              object
#  36  Data Provider                                object
#  37  Data Provider Abbreviation                   object
#  38  Audience Source-Data Provider concatenation  object
#  39  Attribute Category                           object
#  40  Attribute Category Shortcode                 object
#  41  Audience Category Reporting                  object
#  42  Platform                                     object
#  43  Random                                       object
#  44  Prefix                                       object
#  45  Claravine ID                                 object
#  46  submission_name                              object
#  47  submitter_name                               object
#  48  created_date                                 object
# dtypes: float64(5), int64(1), object(43)
# memory usage: 666.5+ MB

# %%
filtered_df = df[(df['Country_x'] == 'United States')
                & (df['Audience Type'] == '3PD')
                & (df['BU'] == 'CSB')]

# %%
grouped_df = filtered_df.groupby(
                                    ['Audience Type Name'
                                     ]).agg({
                                          'Spend': 'sum'
                                        , 'Net Rev': 'sum'
                                      }).reset_index()

grouped_df['ROAS'] = grouped_df['Net Rev'] / grouped_df['Spend']
grouped_df = grouped_df.round(decimals=2, out=None)

# %%
grouped_df
# Out:
#                Audience Type Name        Spend      Net Rev   ROAS
# 0           AFFINITY-3PD BEHAVIOR  31868295.82  33729650.76   1.06
# 1      AUDIO-3PD RETARGET EXPOSED    128248.18      1238.00   0.01
# 2                  BEHAVIORAL-3PD    195860.69   5482328.44  27.99
# 3         BEHAVIORAL-3PD RETARGET         0.00      1949.97    inf
# 4                CAMPAIGN-3PD LAL         0.00     19632.71    inf
# 5         CATEGORY-3PD CONTEXTUAL  21393346.76   6805603.41   0.32
# 6                  CONTEXTUAL-3PD    587132.67         0.00   0.00
# 7         CONTEXTUAL-3PD RETARGET         0.00         0.00    NaN
# 8                     CRM-3PD LAL    170273.97    177651.59   1.04
# 9        CTV-3PD RETARGET EXPOSED    342687.72         0.00   0.00
# 10   DIGITAL-3PD RETARGET EXPOSED    272231.56    192729.53   0.71
# 11               DMP-3PD AUDIENCE   3512021.54   1445712.22   0.41
# 12                    DMP-3PD LAL    396152.13   2102590.63   5.31
# 13          DOMAIN-3PD CONTEXTUAL   4543652.51   1259381.66   0.28
# 14         IN MARKET-3PD BEHAVIOR   5270805.84  11068034.65   2.10
# 15       IN MARKET-3PD CONTEXTUAL    556707.70   4547074.68   8.17
# 16         IN-MARKET-3PD BEHAVIOR         0.00         0.00    NaN
# 17             KCT-3PD CONTEXTUAL    564808.81   1901555.78   3.37
# 18            KSTD-3PD CONTEXTUAL         0.00         0.00    NaN
# 19     MEDIA-3PD RETARGET EXPOSED     21386.31      8559.81   0.40
# 20                  PIXEL-3PD LAL   4126153.14   2809703.20   0.68
# 21           PIXEL-3PD LAL-FAMILY         0.00         0.00    NaN
# 22          PIXEL-3PD LAL-PRODUCT         0.00         0.00    NaN
# 23         PROXIMITY-3PD BEHAVIOR     63626.44      3284.99   0.05
# 24                    ROS-3PD PMP         0.00    150745.77    inf
# 25                    ROS-3PD ROS         0.00         0.00    NaN
# 26    SITE IN MARKET-3PD BEHAVIOR    506550.80   2122014.16   4.19
# 27  SITE IN MARKET-3PD CONTEXTUAL      6985.07         0.00   0.00
# 28     VIDEO-3PD RETARGET EXPOSED    209423.85     27894.79   0.13
