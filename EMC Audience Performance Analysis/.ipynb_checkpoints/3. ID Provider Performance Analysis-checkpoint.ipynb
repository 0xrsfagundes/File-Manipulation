# %%
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('csv/Audience Report Formatted.csv')

df_claravine = pd.read_csv('csv/Claravine.csv')

# %%
df_merged = pd.merge(df, df_claravine, on ='Segment ID', how='left')

# %%
df_merged.fillna(0, inplace=True)

# %%
df_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49282 entries, 0 to 49281
# Data columns (total 64 columns):
#  #   Column                                       Non-Null Count  Dtype
# ---  ------                                       --------------  -----
#  0   Unnamed: 0                                   49282 non-null  int64
#  1   Funnel                                       49282 non-null  object
#  2   Country_x                                    49282 non-null  object
#  3   Dell Fiscal Quarter                          49282 non-null  object
#  4   Vehicle                                      49282 non-null  object
#  5   BU_lvl2                                      49282 non-null  object
#  6   Display Report Site Name                     49282 non-null  object
#  7   Campaign Name                                49282 non-null  object
#  8   Media Buy Name                               49282 non-null  object
#  9   Display BRR Line Item                        49282 non-null  object
#  10  Audience Type Category (Raw)                 49282 non-null  object
#  11  Spend                                        49282 non-null  float64
#  12  Impressions                                  49282 non-null  float64
#  13  Clicks                                       49282 non-null  float64
#  14  True Conversion                              49282 non-null  float64
#  15  True Revenue                                 49282 non-null  float64
#  16  US CSB CT+VT Conversions                     49282 non-null  float64
#  17  US CSB CT+VT Revenue                         49282 non-null  float64
#  18  US BU Visits                                 49282 non-null  float64
#  19  US Total Visits                              49282 non-null  float64
#  20  HVE                                          49282 non-null  float64
#  21  FM MAPs OA                                   49282 non-null  float64
#  22  US DPID Total Revenue                        49282 non-null  float64
#  23  BU_lvl1                                      49282 non-null  object
#  24  9th Element                                  49282 non-null  object
#  25  Audience ID                                  49282 non-null  object
#  26  Audience Composition_x                       49282 non-null  object
#  27  Country-BU                                   49282 non-null  object
#  28  Data provider                                49282 non-null  object
#  29  AIQ Attribute Category                       49282 non-null  object
#  30  1/2/3 PD                                     49282 non-null  object
#  31  Audience ID Group                            49282 non-null  object
#  32  Audience Type Category                       49282 non-null  object
#  33  Revenue                                      49282 non-null  float64
#  34  Segment ID                                   49282 non-null  object
#  35  Audience ID Exists                           49282 non-null  object
#  36  Dell Audience Name                           49282 non-null  object
#  37  VAR Dell Audience Name                       49282 non-null  object
#  38  Dell Audience Name concatenation             49282 non-null  object
#  39  MediaCom Audience Name                       49282 non-null  object
#  40  MediaCom Audience Name Concatenation         49282 non-null  object
#  41  Audience Objective                           49282 non-null  object
#  42  Seed Information                             49282 non-null  object
#  43  Audience Composition_y                       49282 non-null  object
#  44  Audience Composition concatenation           49282 non-null  object
#  45  Audience Object-Audience Composition         49282 non-null  object
#  46  Country_y                                    49282 non-null  object
#  47  Business Unit                                49282 non-null  object
#  48  Country-BU concatenation                     49282 non-null  object
#  49  Data Type                                    49282 non-null  object
#  50  Audience Source                              49282 non-null  object
#  51  Data Provider                                49282 non-null  object
#  52  Data Provider Abbreviation                   49282 non-null  object
#  53  Audience Source-Data Provider concatenation  49282 non-null  object
#  54  Attribute Category                           49282 non-null  object
#  55  Attribute Category Shortcode                 49282 non-null  object
#  56  Audience Category Reporting                  49282 non-null  object
#  57  Platform                                     49282 non-null  object
#  58  Random                                       49282 non-null  object
#  59  Prefix                                       49282 non-null  object
#  60  Claravine ID                                 49282 non-null  object
#  61  submission_name                              49282 non-null  object
#  62  submitter_name                               49282 non-null  object
#  63  created_date                                 49282 non-null  object
# dtypes: float64(13), int64(1), object(50)
# memory usage: 24.1+ MB

# %%
df_merged['Data Provider'].unique()
# Out:
# array([0, 'Oracle Data Marketplace', 'Alliant', '123Push', '3P Multiple',
#        '33Across', 'CEP', 'CIP', 'Lotame', 'comScore',
#        '180byTwo-Dun and Bradstreet-Eyeota', 'AIQ',
#        'Oracle DLX-Oracle Data Marketplace', 'Bluekai-Bombora-Oracle DLX',
#        'Skydeo', 'Dun and Bradstreet',
#        '123Push-Data Axle-Equifax IXI-Experian-Netwise-Webbula',
#        'Dun and Bradstreet-Eyeota', 'Adstra', '180byTwo',
#        '#Home by Vendigi-123Push',
#        '123Push-33Across-Ameribase-AnalyticsIQ-Data Axle-Experian-Netwise-Webbula',
#        'Eyeota', '123Push-180byTwo from Anteriad-33Across',
#        '180byTwo from Anteriad-D&B',
#        'Dun and Bradstreet-Eyeota-Trusignal',
#        'AdAdvisor Audiences by Neustar', '123Push-AnalyticsIQ',
#        'Data Axle', '180byTwo from Anteriad',
#        '180byTwo from Anteriad-Data Axle',
#        'Aberdeen-Alliant-Data Axle-Gravy-Netwise-Start.io',
#        '180byTwo-Bombora-Dun and Bradstreet-Eyeota',
#        'Acxiom-Alliant-Ameribase-AnalyticsIQ-Bluekai-Experian-LBDigital-Lotame-Oracle DLX-Oracle Data Marketplace-ShareThis-Webbula-Ziff Davis',
#        'Bombora-Experian-Eyeota-Webbula-Who2 by NetWise', 'Lotame-TL1',
#        'Data Alliance-Skydeo', 'Datonics-Experian',
#        'Data Alliance-Datonics-eXelate', 'Affinity Answers-Data Alliance',
#        'Data Alliance-Oracle', 'AdSquare Alliance-Roy morgan',
#        'Data Alliance-eXelate', 'Data Alliance-Eyeota', 'Dynata',
#        'Data Alliance-Experian', 'Data Alliance-Datonics-Lotame',
#        'Start.io', 'Acxiom-Eyeota-OnAudience',
#        'AnalyticsIQ-Data Alliance-TL1',
#        'AnalyticsIQ-Data Alliance-OnAudience',
#        'Acxiom-Affinity Answers-Data Alliance-Visual DNA',
#        'Affinity Answers-Special Marketing Services', 'Experian',
#        'Acxiom-OnAudience', 'Acxiom-Data Alliance-Eyeota',
#        'AnalyticsIQ-Data Alliance-Skydeo', 'Acxiom-Oracle'], dtype=object)

# %%
# Grouping columns
grouping_cols = ['Funnel'
                 , 'Country_x'
                 , 'Dell Fiscal Quarter'
                 , 'Vehicle'
                 , 'BU_lvl2'
                 , 'BU_lvl1'
                 , 'Campaign Name'
                 , 'Audience Type Category'
                 , 'Audience Source'
                 , 'Data Provider'
                ]

# Aggregation functions
agg_funcs = {
    'Spend': 'sum',
    'Revenue': 'sum'
}

# Create the new dataframe
grouped_df = df_merged.groupby(grouping_cols).agg(agg_funcs).reset_index()

# Calculate ROAS
grouped_df['ROAS'] = grouped_df['Revenue'] / grouped_df['Spend']

# Round the values in the 'grouped_df' DataFrame to two decimal places
grouped_df = grouped_df.round(decimals=2, out=None)

# %%
grouped_csb_df = grouped_df[grouped_df['BU_lvl1'].isin(['CSB'])]

grouped_b2b_df = grouped_df[grouped_df['BU_lvl1'].isin(['B2B'])]

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('FY24Q2 CT+VT ROAS boxplot by Audience Source - CSB')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_csb_df, x='Audience Source', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('FY24Q2 CT+VT ROAS boxplot by Audience Source - CSB')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_csb_df, x='Data Provider', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('FY24Q2 CT+VT ROAS boxplot by Audience Source - B2B')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_b2b_df, x='Audience Source', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('FY24Q2 CT+VT ROAS boxplot by Audience Source - B2B')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_b2b_df, x='Data Provider', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []
