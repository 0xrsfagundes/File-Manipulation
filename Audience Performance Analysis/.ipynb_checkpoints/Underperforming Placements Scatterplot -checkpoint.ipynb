# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import warnings

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
folder_path = r'C:\Users\Rafael_Fagundes\Downloads\compiled_data.csv'

df = pd.read_csv(folder_path)

# %%
df = df[
         (df['Spend'] > 0) 
          & (df['Net Rev'] > 0)
          & (~df['Display Funnel Mapped'].isin(['Passive Prospects', 'Demand Creation']))
          & (df['Fiscal Quarter'].isin(['2024-Q3']))
          & (df['BU'].isin(['CSB']))
          & (df['Country_x'].isin(['United States']))
          & (df['Display Dell Vehicle Mapped'].isin(['Display']))
          & (df['Audience Type'].isin(['3PD']))
         ]

# %%
info_dict = {
    'Column': df.columns,
    'Non-Null Count': df.count().values,
    'Dtype': df.dtypes.values
}

pd.DataFrame(info_dict)
# Out:
#                                          Column  Non-Null Count    Dtype
# 0                                    Unnamed: 0             930    int64
# 1                                 Audience Type             930   object
# 2                                        Tactic             930   object
# 3                                Media Buy Name             930   object
# 4                                 Campaign Name             930   object
# 5                                Fiscal Quarter             930   object
# 6                                   Fiscal Week             930   object
# 7                                     Country_x             930   object
# 8                         Display Funnel Mapped             930   object
# 9                   Display Dell Vehicle Mapped             930   object
# 10                 Display Business Unit Mapped             930   object
# 11                     Display Site Name Mapped             930   object
# 12                           Audience Type Name             930   object
# 13                                  Impressions             930  float64
# 14                                       Clicks             930  float64
# 15                                        Spend             930  float64
# 16                                      Net Rev             930  float64
# 17                                           BU             930   object
# 18                                   Segment ID             930   object
# 19                           Audience ID Exists             930   object
# 20                           Dell Audience Name             930   object
# 21                       VAR Dell Audience Name             930   object
# 22             Dell Audience Name concatenation             930   object
# 23                       MediaCom Audience Name             930   object
# 24         MediaCom Audience Name Concatenation             930   object
# 25                           Audience Objective             930   object
# 26                             Seed Information             930   object
# 27                         Audience Composition             930   object
# 28           Audience Composition concatenation             930   object
# 29         Audience Object-Audience Composition             930   object
# 30                                    Country_y             930   object
# 31                                Business Unit             930   object
# 32                     Country-BU concatenation             930   object
# 33                                    Data Type             930   object
# 34                              Audience Source             930   object
# 35                                Data Provider             930   object
# 36                   Data Provider Abbreviation             930   object
# 37  Audience Source-Data Provider concatenation             930   object
# 38                           Attribute Category             930   object
# 39                 Attribute Category Shortcode             930   object
# 40                  Audience Category Reporting             930   object
# 41                                     Platform             930   object
# 42                                       Random             930   object
# 43                                       Prefix             930   object
# 44                                 Claravine ID             930   object
# 45                              submission_name             930   object
# 46                               submitter_name             930   object
# 47                                 created_date             930   object

# %%
box_df = df.groupby(['Campaign Name','Media Buy Name'])[['Impressions', 'Clicks', 'Spend', 'Net Rev']].sum().reset_index()
box_df['ROAS'] = box_df['Net Rev'] / box_df['Spend']  # Fix the assignment to 'ROAS'
box_df['CTR'] = box_df['Clicks'] / box_df['Impressions']  # Fix the assignment to 'CTR'
box_df['CPC'] = box_df['Spend'] / box_df['Clicks']  # Fix the assignment to 'CTR'

# %%
box_df[box_df['ROAS'] < 1].sort_values(by=['CTR'],ascending=True)
# Out:
#                                           Campaign Name  \
# 5          2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 431               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 326       2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_PBU
# 270       2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_PBU
# 244    2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_DIRECT
# 172             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 95         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 16         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 335       2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_PBU
# 258    2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_DIRECT
# 366        2024_Q3_US_SBG-ISG_AP_DISPLAY_PROSPECTING_NA
# 432               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 215   2024_Q3_US_CSBO-CSB_AP_DISPLAY_PROSPECTING_NATIVE
# 114       2024_Q3_US_CSBO-CON_AP_DISPLAY_PROSPECTING_NA
# 2          2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 115       2024_Q3_US_CSBO-CON_AP_DISPLAY_PROSPECTING_NA
# 437               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 175             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 7          2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 387        2024_Q3_US_SBG-ISG_AP_DISPLAY_PROSPECTING_NA
# 192             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 199   2024_Q3_US_CSBO-CSB_AP_DISPLAY_PROSPECTING_NATIVE
# 246    2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_DIRECT
# 190             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 59         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 415  2024_Q3_US_SBG-PROGRAMS_AP_DISPLAY_PROSPECTING_SBA
# 369        2024_Q3_US_SBG-ISG_AP_DISPLAY_PROSPECTING_NA
# 439               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 170             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 183             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 249    2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_DIRECT
# 180             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 254    2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_DIRECT
# 87         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 235    2024_Q3_US_CSBO-SB_AP_DISPLAY_PROSPECTING_DIRECT
# 65         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 13         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 178             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 185             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 379        2024_Q3_US_SBG-ISG_AP_DISPLAY_PROSPECTING_NA
# 380        2024_Q3_US_SBG-ISG_AP_DISPLAY_PROSPECTING_NA
# 367        2024_Q3_US_SBG-ISG_AP_DISPLAY_PROSPECTING_NA
# 58         2024_Q3_US_CSBO-AW_AP_DISPLAY_PROSPECTING_NA
# 430               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 165             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 423               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 435               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 193             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 417        2024_Q3_US_SBG-PROGRAMS_LG_DISPLAY_BRAND_DEN
# 168             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 418               2024_Q3_US_SBG-SB_HP_DISPLAY_BRAND_NA
# 402  2024_Q3_US_SBG-PROGRAMS_AP_DISPLAY_PROSPECTING_DFS
# 169             2024_Q3_US_CSBO-CON_HP_DISPLAY_BRAND_NA
# 400  2024_Q3_US_SBG-PROGRAMS_AP_DISPLAY_PROSPECTING_DFS
#
#                                                                                                                                       Media Buy Name  \
# 5         AMAZON_CATEGORY-3PD Contextual_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_Streaming TV Retargeting Dell Site_Always On AW X16 Nexus
# 431                                    DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_970x250_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Site-WSJ-Display_Desktop
# 326                                        DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_728x90_DCPM_INTEL CCF_STD_FY24Q3_NA_Google-LAL-Deals_Desktop-WTN
# 270                                  AMAZON_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x600_DCPM_INTEL CCF_STD_FY24Q3_NA_Card Users_Desktop-Amazon-Vostro
# 244                                                 YAHOO_AFFINITY-3PD BEHAVIOR_DCO-DISPLAY_728x90_DCPC_INTEL CCF_STD_FY24Q3_NA_SBDMs-Desktop-ODC_NA
# 172                      DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_1x1_CPM_INTEL CCF_CT_FY24Q3_NA_Vox Athena In Feed Unit DESKTOP PMP Sitelist_WTN 6s
# 95                         YAHOO_DIGITAL-3PD RETARGET EXPOSED_DCO-DISPLAY_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_AW Ad Exposure Retargeting_AW ODC CCF
# 16                                                  DV360_DMP-3PD LAL_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_LAL Cart_AW M18 Infinity CCF
# 335               DV360_DMP-3PD AUDIENCE_DCO-DISPLAY_300x250_DCPM_INTEL CCF_STD_FY24Q3_drasbf8bmwy-targeting-sbdmconsumers-3pofftheshelf_Desktop-ODC
# 258                                             YAHOO_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_728x90_DCPM_INTEL CCF_STD_FY24Q3_NA_Mobile-Predict_NA-Teton
# 366                                     DV360_IN MARKET-3PD CONTEXTUAL_HTML5 BANNER_300x250_CPM_INTEL DCF_STD_FY24Q3_NA_Unbranded-Keyword-Desktop_NA
# 432                                             DV360_AFFINITY-3PD BEHAVIOR_VID IN-STREAM_15 SEC_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Site-BI_Desktop
# 215                      DV360_IN MARKET-3PD BEHAVIOR_NATIVE_1x1_DCPM_INTEL CCF_CT_FY24Q3_NA_PMP Sitelist YieldMo Executives_DISPLAY XPS13 Millennio
# 114                           AMAZON_IN MARKET-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_In Market Computers 500 OE_DISPLAY XPS
# 2    AMAZON_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_Twitch Audience PC Game Viewers Dell Site_Always On AW X16 Nexus
# 115                           AMAZON_IN MARKET-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_In Market Computers 750 OE_DISPLAY XPS
# 437                                              DV360_AFFINITY-3PD BEHAVIOR_VID IN-STREAM_30 SEC_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Site-BI_Mobile
# 175                                             DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_CPM_INTEL CCF_STD_FY24Q3_NA_Genius PMP Sitelist_WTN
# 7                            AMAZON_DMP-3PD LAL_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_LAL 1PD Audiences Dell Site_Always On AW X16 Nexus
# 387                                     DV360_SITE IN MARKET-3PD BEHAVIOR_VID IN-STREAM_30 SEC_CPM_INTEL DCF_STD_FY24Q3_NA_Custom-Affinity-Mobile_NA
# 192                                            DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_728x90_CPM_INTEL CCF_STD_FY24Q3_NA_Meredith PMP Sitelist_WTN
# 199                           DV360_IN MARKET-3PD BEHAVIOR_NATIVE_1x1_DCPM_INTEL CCF_CT_FY24Q3_NA_PMP Sitelist Taboola ITDMs_DISPLAY XPS13 Millennio
# 246                                              YAHOO_AFFINITY-3PD BEHAVIOR_DCO-DISPLAY_970x250_DCPM_INTEL CCF_STD_FY24Q3_NA_Desktop-Predict-ODC_NA
# 190                                           DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_728x90_CPM_INTEL CCF_STD_FY24Q3_NA_Index KCT PMP Sitelist_WTN
# 59                         YAHOO_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF SMF_STD_FY24Q3_NA_College Students_Desktop AW Bastion SMF
# 415                                                   DV360_DMP-3PD AUDIENCE_HTML5 BANNER_728x90_DCPM_MSFT JS HOME OEM+WIN_STD_FY24Q3_NA_Dental_Test
# 369                                       DV360_IN MARKET-3PD CONTEXTUAL_HTML5 BANNER_320x50_CPM_INTEL DCF_STD_FY24Q3_NA_Unbranded-Keyword-Mobile_NA
# 439                                         DV360_AFFINITY-3PD BEHAVIOR_VID IN-STREAM_30 SEC_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Site-Forbes_Desktop
# 170                                        DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_160x600_CPM_INTEL CCF_STD_FY24Q3_NA_Magnite KCT PMP Sitelist_WTN
# 183                                             DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x600_CPM_INTEL CCF_STD_FY24Q3_NA_Genius PMP Sitelist_WTN
# 249                                             YAHOO_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPC_INTEL CCF_STD_FY24Q3_NA_SBDMs-Desktop_NA-Teton
# 180                                         DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x600_CPM_INTEL CCF_STD_FY24Q3_NA_Conde Nast PMP Sitelist_WTN
# 254                                           YAHOO_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x600_DCPM_INTEL CCF_STD_FY24Q3_NA_Desktop-Predict_NA-Teton
# 87                      YAHOO_CATEGORY-3PD CONTEXTUAL_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_Predictive Segments_Desktop AW X16 Nexus CCF
# 235                                         YAHOO_AFFINITY-3PD BEHAVIOR_DCO-DISPLAY-MOBILE_320x50_DCPM_INTEL CCF_STD_FY24Q3_NA_Mobile-Predict-ODC_NA
# 65                                YAHOO_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF_STD_FY24Q3_NA_Core Gamers_Desktop AW X16 Nexus CCF
# 13                                                   DV360_DMP-3PD LAL_HTML5 BANNER_160x600_DCPM_INTEL CCF SMF_STD_FY24Q3_NA_LAL Cart_AW Bastion SMF
# 178                                           DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_CPM_INTEL CCF_STD_FY24Q3_NA_Meredith PMP Sitelist_WTN
# 185                                        DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x600_CPM_INTEL CCF_STD_FY24Q3_NA_Magnite KCT PMP Sitelist_WTN
# 379                                      DV360_SITE IN MARKET-3PD BEHAVIOR_HTML5 BANNER_320x50_CPM_INTEL DCF_STD_FY24Q3_NA_Custom-Affinity-Mobile_NA
# 380                                    DV360_SITE IN MARKET-3PD BEHAVIOR_HTML5 BANNER_320x50_CPM_INTEL DCF_STD_FY24Q3_NA_Network-Equipment-Mobile_NA
# 367                                      DV360_IN MARKET-3PD CONTEXTUAL_HTML5 BANNER_300x250_CPM_INTEL DCF_STD_FY24Q3_NA_Unbranded-Keyword-Mobile_NA
# 58                            YAHOO_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_DCPM_INTEL CCF SMF_STD_FY24Q3_NA_Casual Gamers_Desktop AW Bastion SMF
# 430                               DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_970x250_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Site-The-Week-Display_Desktop
# 165                                  CONDE NAST_AFFINITY-3PD BEHAVIOR_STANDARD BANNER_1x1_CPM_INTEL CCF_CT_FY24Q3_NA_Ars Technica_Native Tile Driver
# 423                      DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_300x250_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Sitelist-Digital-Trends-Display_Mobile
# 435                                            DV360_AFFINITY-3PD BEHAVIOR_VID IN-STREAM_15 SEC_CPM_INTEL CCF SMF_STD_FY24Q3_NA_PMP-Site-WSJ_Desktop
# 193                                           DV360_AFFINITY-3PD BEHAVIOR_HTML5 BANNER_728x90_CPM_INTEL CCF_STD_FY24Q3_NA_Permutive PMP Sitelist_WTN
# 417                                                           SPICEWORKS_CATEGORY-3PD CONTEXTUAL_NA_1x1_CPL_INTEL IIF CS_CT_FY24Q3_NA_Quickslider_NA
# 168                       DV360_AFFINITY-3PD BEHAVIOR_HIGH IMPACT_1x1_DCPM_INTEL CCF_CT_FY24Q3_NA_PMP-Wunderkind_WTN-Active-Prospect-Mobile-Masthead
# 418                                              DV360_AFFINITY-3PD BEHAVIOR_HIGH IMPACT_1x1_CPM_INTEL CCF SMF_CT_FY24Q3_NA_Undertone Pagegrabber_NA
# 402                                                 DV360_AFFINITY-3PD BEHAVIOR_VID IN-STREAM_30 SEC_DCPM_INTEL CCF_STD_FY24Q3_NA_DFS-LAL_Mobile-OLV
# 169                        DV360_AFFINITY-3PD BEHAVIOR_HIGH IMPACT_1x1_DCPM_INTEL CCF_CT_FY24Q3_NA_PMP-Wunderkind_WTN-Active-Prospect-Mobile-Overlay
# 400                       DV360_AFFINITY-3PD BEHAVIOR_VID IN-STREAM_30 SEC_DCPM_INTEL CCF_STD_FY24Q3_NA_DFS-Custom-Affinity-Entrepreneurs_Mobile-OLV
#
#      Impressions   Clicks        Spend  Net Rev      ROAS       CTR
# 5        21672.0      0.0   166.523012   118.47  0.711433  0.000000
# 431       2039.0      0.0    56.674959    39.99  0.705603  0.000000
# 326       5474.0      0.0    30.218924    29.99  0.992424  0.000000
# 270       9203.0      0.0    49.528900    39.99  0.807407  0.000000
# 244       9424.0      0.0    33.100000    19.99  0.603927  0.000000
# 172     228349.0      2.0  3257.019997  1261.97  0.387462  0.000009
# 95      367375.0     14.0   517.030000   364.96  0.705878  0.000038
# 16      496828.0     25.0   451.348580    99.00  0.219343  0.000050
# 335     230750.0     15.0   146.146851    39.00  0.266855  0.000065
# 258      99035.0      9.0   245.120000    39.99  0.163145  0.000091
# 366      50382.0      5.0   254.208177    59.00  0.232093  0.000099
# 432      60172.0      6.0   514.181240   232.97  0.453089  0.000100
# 215     292179.0     30.0   286.208203   204.52  0.714585  0.000103
# 114      16815.0      2.0   104.764033     9.99  0.095357  0.000119
# 2        22937.0      3.0   134.118032   103.99  0.775362  0.000131
# 115      14933.0      2.0    88.943377    59.00  0.663343  0.000134
# 437      66041.0      9.0   333.709875   161.93  0.485242  0.000136
# 175     485578.0     74.0  2771.899600  2621.96  0.945907  0.000152
# 7        36179.0      6.0   152.593677    88.00  0.576695  0.000166
# 387     223811.0     38.0   193.870111   117.00  0.603497  0.000170
# 192     155752.0     28.0  1110.920894    59.00  0.053109  0.000180
# 199     118129.0     27.0   400.936718   190.33  0.474713  0.000229
# 246      16156.0      4.0    70.640000    59.99  0.849236  0.000248
# 190     205196.0     51.0   796.651562   438.26  0.550128  0.000249
# 59       42547.0     11.0    94.900000    36.99  0.389779  0.000259
# 415       7657.0      2.0    58.235006    39.99  0.686700  0.000261
# 369     295868.0     80.0  1157.936006   668.98  0.577735  0.000270
# 439       7350.0      2.0   225.837000   207.99  0.920974  0.000272
# 170     123752.0     34.0   643.114915   168.99  0.262768  0.000275
# 183     630041.0    178.0  3581.161985  2843.85  0.794114  0.000283
# 249     128186.0     37.0   282.510000    79.97  0.283070  0.000289
# 180     689965.0    211.0  6272.252260  5413.07  0.863019  0.000306
# 254      59861.0     20.0   249.010000    94.98  0.381430  0.000334
# 87       54247.0     19.0   139.450000    39.00  0.279670  0.000350
# 235     579543.0    205.0  1958.170000   212.97  0.108760  0.000354
# 65       67208.0     24.0   128.340000    99.00  0.771388  0.000357
# 13      201319.0     74.0   456.301318    29.99  0.065724  0.000368
# 178     263861.0     97.0  1895.612646   329.98  0.174076  0.000368
# 185      93773.0     36.0   535.689972   107.98  0.201572  0.000384
# 379     978570.0    437.0  2709.557023  1157.05  0.427026  0.000447
# 380    2067266.0   1015.0  5221.967551  4053.27  0.776196  0.000491
# 367      32806.0     19.0   153.685361    99.00  0.644173  0.000579
# 58       12934.0      8.0    34.870000    20.69  0.593347  0.000619
# 430      11095.0      7.0    89.829780    33.24  0.370033  0.000631
# 165     329058.0    378.0  3851.188421  3299.48  0.856743  0.001149
# 423      50273.0     63.0   689.304020    74.99  0.108791  0.001253
# 435       3060.0      7.0   176.345781    79.96  0.453427  0.002288
# 193      21871.0     54.0   141.031714    35.98  0.255120  0.002469
# 417      22070.0     81.0   754.794000   101.99  0.135123  0.003670
# 168     525559.0   3424.0  6469.479709  2114.89  0.326903  0.006515
# 418     587088.0   7097.0  9209.544885  5321.01  0.577771  0.012088
# 402     131763.0   2847.0   406.199323    59.00  0.145249  0.021607
# 169     383679.0  13668.0  5081.044821  1364.04  0.268457  0.035624
# 400      69494.0   3726.0   466.623010   304.99  0.653611  0.053616
