# %%
import warnings
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', None)

# %%
csv_file = "csv/Audience Report Formatted.csv"
df = pd.read_csv(csv_file)

# %%
df.head()
# Out:
#    Unnamed: 0                   Funnel    Country Dell Fiscal Quarter Vehicle  \
# 0           0  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 1           1  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 2           2  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 3           3  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 4           4  Brand Seeker/Purchasers  Australia              FY24Q1   Video
#
#      BU_lvl2 Display Report Site Name  \
# 0  Alienware                   Fandom
# 1  Alienware                   Fandom
# 2  Alienware                   Fandom
# 3  Alienware                   Fandom
# 4  Alienware                   Fandom
#
#                                        Campaign Name  \
# 0  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 1  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 2  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 3  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 4  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
#
#                                       Media Buy Name Display BRR Line Item  \
# 0  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERH...                     0
# 1  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERD...                     0
# 2  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERD...                     0
# 3  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERD...                     0
# 4  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERM...                     0
#
#   Audience Type Category (Raw)        Spend  Impressions  Clicks  \
# 0        DOMAIN-3PD CONTEXTUAL     0.000000     464233.0   407.0
# 1        DOMAIN-3PD CONTEXTUAL     0.000000     351621.0   660.0
# 2        DOMAIN-3PD CONTEXTUAL     0.000000     993757.0  1652.0
# 3        DOMAIN-3PD CONTEXTUAL  4518.771338     230321.0   341.0
# 4        DOMAIN-3PD CONTEXTUAL  3168.728508     158126.0   109.0
#
#    True Conversion (GCSB) (Calc)  True Revenue  US CSB CT+VT Conversions  \
# 0                            0.0    736.694720                       2.0
# 1                            0.0      0.000000                       0.0
# 2                            0.0      0.118731                       0.0
# 3                            0.0      0.000000                       1.0
# 4                            0.0    559.388025                       1.0
#
#    US CSB CT+VT Revenue  US BU Visits  US Total Visits  \
# 0           1001.209664         172.0              0.0
# 1              0.000000         235.0              0.0
# 2              0.000000         626.0              0.0
# 3            404.307400         158.0              0.0
# 4            245.011648          56.0              0.0
#
#    Total COM HVEs 4.0 Custom (Calc) Updated  FM MAPs OA  \
# 0                                      83.0         0.0
# 1                                      59.0         0.0
# 2                                     123.0         0.0
# 3                                      61.0         0.0
# 4                                      65.0         0.0
#
#    US DPID Total Revenue BU_lvl1 9th Element Audience ID Audience Composition  \
# 0                910.190     CSB           0       CHECK                CHECK
# 1                  0.000     CSB           0       CHECK                CHECK
# 2                  0.000     CSB           0       CHECK                CHECK
# 3                367.552     CSB           0       CHECK                CHECK
# 4                222.737     CSB           0       CHECK                CHECK
#
#   Country-BU Data provider AIQ Attribute Category               1/2/3 PD  \
# 0      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 1      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 2      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 3      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 4      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
#
#   Audience ID Group Audience Type Category      Revenue
# 0             CHECK  DOMAIN-3PD CONTEXTUAL  1001.209664
# 1             CHECK  DOMAIN-3PD CONTEXTUAL     0.000000
# 2             CHECK  DOMAIN-3PD CONTEXTUAL     0.000000
# 3             CHECK  DOMAIN-3PD CONTEXTUAL   404.307400
# 4             CHECK  DOMAIN-3PD CONTEXTUAL   245.011648

# %%
df.head()
# Out:
#    Unnamed: 0                   Funnel    Country Dell Fiscal Quarter Vehicle  \
# 0           0  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 1           1  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 2           2  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 3           3  Brand Seeker/Purchasers  Australia              FY24Q1   Video
# 4           4  Brand Seeker/Purchasers  Australia              FY24Q1   Video
#
#      BU_lvl2 Display Report Site Name  \
# 0  Alienware                   Fandom
# 1  Alienware                   Fandom
# 2  Alienware                   Fandom
# 3  Alienware                   Fandom
# 4  Alienware                   Fandom
#
#                                        Campaign Name  \
# 0  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 1  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 2  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 3  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
# 4  2024_1H_AU_CSBO-AW_BSP_DISPLAY_PROSPECTING_DEM...
#
#                                       Media Buy Name Display BRR Line Item  \
# 0  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERH...                     0
# 1  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERD...                     0
# 2  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERD...                     0
# 3  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERD...                     0
# 4  ValMorganOnline_Fandom_FANDOMVIDEOFANTAKEOVERM...                     0
#
#   Audience Type Category (Raw)        Spend  Impressions  Clicks  \
# 0        DOMAIN-3PD CONTEXTUAL     0.000000     464233.0   407.0
# 1        DOMAIN-3PD CONTEXTUAL     0.000000     351621.0   660.0
# 2        DOMAIN-3PD CONTEXTUAL     0.000000     993757.0  1652.0
# 3        DOMAIN-3PD CONTEXTUAL  4518.771338     230321.0   341.0
# 4        DOMAIN-3PD CONTEXTUAL  3168.728508     158126.0   109.0
#
#    True Conversion (GCSB) (Calc)  True Revenue  US CSB CT+VT Conversions  \
# 0                            0.0    736.694720                       2.0
# 1                            0.0      0.000000                       0.0
# 2                            0.0      0.118731                       0.0
# 3                            0.0      0.000000                       1.0
# 4                            0.0    559.388025                       1.0
#
#    US CSB CT+VT Revenue  US BU Visits  US Total Visits  \
# 0           1001.209664         172.0              0.0
# 1              0.000000         235.0              0.0
# 2              0.000000         626.0              0.0
# 3            404.307400         158.0              0.0
# 4            245.011648          56.0              0.0
#
#    Total COM HVEs 4.0 Custom (Calc) Updated  FM MAPs OA  \
# 0                                      83.0         0.0
# 1                                      59.0         0.0
# 2                                     123.0         0.0
# 3                                      61.0         0.0
# 4                                      65.0         0.0
#
#    US DPID Total Revenue BU_lvl1 9th Element Audience ID Audience Composition  \
# 0                910.190     CSB           0       CHECK                CHECK
# 1                  0.000     CSB           0       CHECK                CHECK
# 2                  0.000     CSB           0       CHECK                CHECK
# 3                367.552     CSB           0       CHECK                CHECK
# 4                222.737     CSB           0       CHECK                CHECK
#
#   Country-BU Data provider AIQ Attribute Category               1/2/3 PD  \
# 0      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 1      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 2      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 3      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
# 4      CHECK         CHECK                  CHECK  DOMAIN-3PD CONTEXTUAL
#
#   Audience ID Group Audience Type Category      Revenue
# 0             CHECK  DOMAIN-3PD CONTEXTUAL  1001.209664
# 1             CHECK  DOMAIN-3PD CONTEXTUAL     0.000000
# 2             CHECK  DOMAIN-3PD CONTEXTUAL     0.000000
# 3             CHECK  DOMAIN-3PD CONTEXTUAL   404.307400
# 4             CHECK  DOMAIN-3PD CONTEXTUAL   245.011648

# %%
selected_cols = ['Funnel','Country','Dell Fiscal Quarter','Vehicle'
                 ,'BU_lvl1','BU_lvl2','Campaign Name','Audience Type Category'
                 ,'Spend','Revenue']

new_df = df[selected_cols]

# %%
# Grouping columns
grouping_cols = ['Funnel', 'Country', 'Dell Fiscal Quarter', 'Vehicle', 'BU_lvl2', 'BU_lvl1', 'Campaign Name', 'Audience Type Category']

# Aggregation functions
agg_funcs = {
    'Spend': 'sum',
    'Revenue': 'sum'
}

# Create the new dataframe
grouped_df = new_df.groupby(grouping_cols).agg(agg_funcs).reset_index()

# Calculate ROAS
grouped_df['ROAS'] = grouped_df['Revenue'] / grouped_df['Spend']

# Round the values in the 'grouped_df' DataFrame to two decimal places
grouped_df = grouped_df.round(decimals=2, out=None)

# Print or display the new dataframe
grouped_df.head()
# Out:
#              Funnel    Country Dell Fiscal Quarter Vehicle  \
# 0  Active Prospects     ANDEAN              FY24Q2  Social
# 1  Active Prospects     ANDEAN              FY24Q2  Social
# 2  Active Prospects  Argentina              FY24Q2  Social
# 3  Active Prospects  Argentina              FY24Q2  Social
# 4  Active Prospects  Argentina              FY24Q2  Social
#
#                           BU_lvl2 BU_lvl1  \
# 0          Client Solutions Group     B2B
# 1          Client Solutions Group     B2B
# 2  Infrastructure Solutions Group     B2B
# 3  Infrastructure Solutions Group     B2B
# 4  Infrastructure Solutions Group     B2B
#
#                                        Campaign Name  Audience Type Category  \
# 0  2024_Q1_ANDEAN-CO_CSG_AP_SOCIAL_PROSPECTING-EN...  IN MARKET-3PD BEHAVIOR
# 1  2024_Q1_ANDEAN-CO_CSG_AP_SOCIAL_PROSPECTING-EN...  IN MARKET-3PD BEHAVIOR
# 2  2024_Q2_AR_ISG_AP_SOCIAL_PROSPECTING-ENGAGE_SO...  IN MARKET-3PD BEHAVIOR
# 3  2024_Q2_AR_ISG_AP_SOCIAL_PROSPECTING-ENGAGE_SO...  IN MARKET-3PD BEHAVIOR
# 4  2024_Q2_AR_ISG_AP_SOCIAL_PROSPECTING-ENGAGE_SO...  IN MARKET-3PD BEHAVIOR
#
#      Spend  Revenue  ROAS
# 0   214.80      0.0   0.0
# 1   321.60      0.0   0.0
# 2   925.38      0.0   0.0
# 3   924.14      0.0   0.0
# 4  1112.93      0.0   0.0

# %%
grouped_df = grouped_df[(grouped_df['Spend'] > 0) 
                        & (~grouped_df['Funnel'].isin(['Passive Prospects', 'Demand Creation'])) 
                        & (grouped_df['Revenue'] > 0) 
                        & (grouped_df['Dell Fiscal Quarter'].isin(['FY24Q2']))]

# %%
grouped_csb_df = grouped_df[(grouped_df['Spend'] > 0) 
                        & (~grouped_df['Funnel'].isin(['Passive Prospects', 'Demand Creation'])) 
                        & (grouped_df['Revenue'] > 0) 
                        & (grouped_df['Dell Fiscal Quarter'].isin(['FY24Q2'])) 
                        & (grouped_df['BU_lvl1'].isin(['CSB']))]

# %%
grouped_b2b_df = grouped_df[(grouped_df['Spend'] > 0) 
                        & (~grouped_df['Funnel'].isin(['Passive Prospects', 'Demand Creation'])) 
                        & (grouped_df['Revenue'] > 0) 
                        & (grouped_df['Dell Fiscal Quarter'].isin(['FY24Q2']))
                        & (grouped_df['BU_lvl1'].isin(['B2B']))]

# %% [markdown]
# <h2>Boxplots for CSB</h2>

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by Funnel')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_csb_df, x='Funnel', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by Country')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_csb_df, x='Country', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by BU lvl2')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_csb_df, x='BU_lvl2', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by Audience Type Category')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_csb_df, x='Audience Type Category', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %% [markdown]
# <h2>Boxplots for B2B</h2>

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot ROAS by Funnel')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_b2b_df, x='Funnel', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by Country')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_b2b_df, x='Country', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by BU lvl2')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_b2b_df, x='BU_lvl2', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %%
# Create a box plot by 'BU_lvl1'
fig, ax1 = plt.subplots(figsize=(10, 5))

# Set plot title and labels
ax1.set_title('ROAS boxplot by Audience Type Category')
ax1.set_ylabel('ROAS')

# Create the box plot
sns.boxplot(data=grouped_b2b_df, x='Audience Type Category', y='ROAS')

plt.axhline(y=1, color='r', linestyle='--', label='ROAS = 1')

plt.xticks(rotation=90)

# Show the plot
plt.semilogy()
# Out:
# []

# %% [markdown]
# <h2>Boxplot Numeric Values</h2>

# %%
boxplot_data = grouped_csb_df.groupby('Funnel')['ROAS'].describe()
boxplot_data
# Out:
#                            count        mean          std   min   25%   50%  \
# Funnel
# Active Prospects           175.0    5.038171     6.552525  0.01  0.41  2.54
# Brand Seeker/Purchasers     83.0   11.662289    26.402014  0.01  0.56  2.89
# High Propensity Prospects   57.0  340.807719  2569.458952  0.00  0.02  0.10
# Lead Gen                     1.0    1.920000          NaN  1.92  1.92  1.92
#
#                              75%       max
# Funnel
# Active Prospects           7.430     39.20
# Brand Seeker/Purchasers    8.425    155.28
# High Propensity Prospects  0.310  19399.46
# Lead Gen                   1.920      1.92

# %%
grouped_csb_df_export = grouped_csb_df[grouped_csb_df['ROAS']<1]
grouped_b2b_df_export = grouped_b2b_df[grouped_b2b_df['ROAS']<1]

grouped_csb_df_export.to_csv('csv/grouped_csb_df_export.csv')
grouped_b2b_df_export.to_csv('csv/grouped_b2b_df_export.csv')
