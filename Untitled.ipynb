# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\rafael_fagundes\Downloads\template_explorer_report_09f111ce-1210-4351-887a-1912f5cbde39.csv', parse_dates=['created_date'])

df['created_date'] = df['created_date'].dt.strftime('%Y-%m-%d') #2011-01-29	

df.rename(columns={'created_date':'Date'}, inplace = True)

df['Date'] = pd.to_datetime(df['Date'])

df.head()
# Out:
#     Segment ID                                 Dell Audience Name  \
# 0   14o04dsyat                                                NaN
# 1  da2z3jfdx3d                                                NaN
# 2  d2l072rynmf  targeting-development-development_us-csbo-csb_...
# 3  dztqn3bkuwh  targeting-development/highdellpropensity/highg...
# 4  dfmb6iq56n5  targeting-im/mb-mbinmarket_us-mb_abm-liveramp-...
#
#                               VAR Dell Audience Name  \
# 0                                                NaN
# 1                                                NaN
# 2  targeting-development-development_us-csbo-csb_...
# 3  targeting-development/highdellpropensity/highg...
# 4  targeting-im/mb-mbinmarket_us-mb_abm-liveramp-...
#
#                     Dell Audience Name concatenation  \
# 0  Seed LAL-gamer-test-provider-MAID+Cookies_us-c...
# 1  3P Data enrichment-inquirer-test_us-csbo-csb_G...
# 2  Targeting-development-development_us-csbo-csb_...
# ...

# %%
calendar = pd.read_csv(r'C:\Users\rafael_fagundes\OneDrive - Dell Technologies\Desktop\New Folder\Calendar.csv', parse_dates=['Date'])

calendar.head()
# Out:
#         Date  Day      FY Qtr Month  Period  WK  QWK        FQ         FQW
# 0 2011-01-29  Sat  FY2012  Q1    M1       1   1    1  FY2012Q1  FY2012Q1W1
# 1 2011-01-30  Sun  FY2012  Q1    M1       1   1    1  FY2012Q1  FY2012Q1W1
# 2 2011-01-31  Mon  FY2012  Q1    M1       1   1    1  FY2012Q1  FY2012Q1W1
# 3 2011-02-01  Tue  FY2012  Q1    M1       1   1    1  FY2012Q1  FY2012Q1W1
# 4 2011-02-02  Wed  FY2012  Q1    M1       1   1    1  FY2012Q1  FY2012Q1W1

# %%
df_merged = pd.merge(df, calendar, on=['Date'], how='left')

df_merged.head()
# Out:
#     Segment ID                                 Dell Audience Name  \
# 0   14o04dsyat                                                NaN
# 1  da2z3jfdx3d                                                NaN
# 2  d2l072rynmf  targeting-development-development_us-csbo-csb_...
# 3  dztqn3bkuwh  targeting-development/highdellpropensity/highg...
# 4  dfmb6iq56n5  targeting-im/mb-mbinmarket_us-mb_abm-liveramp-...
#
#                               VAR Dell Audience Name  \
# 0                                                NaN
# 1                                                NaN
# 2  targeting-development-development_us-csbo-csb_...
# 3  targeting-development/highdellpropensity/highg...
# 4  targeting-im/mb-mbinmarket_us-mb_abm-liveramp-...
#
#                     Dell Audience Name concatenation  \
# 0  Seed LAL-gamer-test-provider-MAID+Cookies_us-c...
# 1  3P Data enrichment-inquirer-test_us-csbo-csb_G...
# 2  Targeting-development-development_us-csbo-csb_...
# ...

# %%
df_merged.to_csv(r'C:\Users\rafael_fagundes\OneDrive - Dell Technologies\Desktop\Claravine.csv')
